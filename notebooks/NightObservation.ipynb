# %%
from ztfquery import query

# %%
night = "20180429"
night_summary = query.NightSummary(night)

# %%
night_summary.get_observed_information()
# Out:
#     field        ra       dec
# 43    364  139.2275   -9.8500
# 44    416  142.6200   -2.6500
# 45    417  149.7100   -2.6500
# 46    467  144.3575    4.5500
# 47    414  128.4400   -2.6500
# 48    619  143.6189   26.1500
# 49    661  101.9372   33.3500
# 50    746  100.7029   47.7500
# 51    837   77.1429   69.3500
# 52    857   84.0000   76.5500
# 53    838   94.2857   69.3500
# 54    783  114.8267   54.9500
# 55    747  110.1276   47.7500
# 56    707  114.6987   40.5500
# 57    708  123.3155   40.5500
# 58    709  131.9323   40.5500
# 59    710  140.5491   40.5500
# 60    749  128.9770   47.7500
# 61    750  138.4017   47.7500
# 62    815  126.6667   62.1500
# 63    785  136.6762   54.9500
# 64    786  147.6010   54.9500
# 65    711  149.1659   40.5500
# 66    786  147.6010   54.9500
# 67    712  157.7828   40.5500
# 68    269  177.6791  -24.2500
# 69    320  185.2193  -17.0500
# 70    422  185.1600   -2.6500
# 71    473  185.3082    4.7100
# 72    525  186.7749   11.5700
# ...

# %%
night_summary.get_observed_field()
# Out:
# array([ 364,  416,  417,  467,  414,  619,  661,  746,  837,  857,  838,
#         783,  747,  707,  708,  709,  710,  749,  750,  815,  785,  786,
#         711,  786,  712,  269,  320,  422,  473,  525,  526,  626,  672,
#         673,  717,  758,  757,  756,  791,  821,  791,  756,  755,  790,
#         820,  844,  862,  844,  820,  790,  819,  843,  752,  841,  817,
#         818,  843,  819,  789,  754,  714,  715,  716,  671,  625,  624,
#         623,  364,  415,  414,  413,  514,  564,  614,  662,  707,  747,
#         782,  746,  706,  661,  613,  660,  705,  745,  781,  812,  838,
#         813,  839,  814,  783,  748,  784,  815,  785,  786,  789,  819,
#         786,  749,  708,  709,  710,  619,  570,  571,  520,  519,  466,
#         416,  467,  623,  622,  621,  620,  668,  669,  670,  668,  712,
#         713,  712,  711,  750,  752,  841,  817,  787,  753,  714,  788,
#         818,  843,  819,  843,  819,  789,  754,  789,  790,  715,  755,
# ...

# %%
night_summary.data
# Out:
#                   UT_START  sun exp fil  type  cnt field pid        ra  \
# 0    2018-04-29T01:58:35.1    5  30   0  dark    1    -1  -1  -99.0000
# 1    2018-04-29T01:59:41.7    5  30   0  dark    2    -1  -1  -99.0000
# 2    2018-04-29T02:00:46.7    5  30   0  dark    3    -1  -1  -99.0000
# 3    2018-04-29T02:01:53.2    4   0   0  bias    1    -1  -1  -99.0000
# 4    2018-04-29T02:02:28.7    4   0   0  bias    2    -1  -1  -99.0000
# 5    2018-04-29T02:03:04.9    4   0   0  bias    3    -1  -1  -99.0000
# 6    2018-04-29T02:03:39.7    4   0   0  bias    4    -1  -1  -99.0000
# 7    2018-04-29T02:04:15.7    4   0   0  bias    5    -1  -1  -99.0000
# 8    2018-04-29T02:04:50.7    4   0   0  bias    6    -1  -1  -99.0000
# 9    2018-04-29T02:05:26.7    4   0   0  bias    7    -1  -1  -99.0000
# 10   2018-04-29T02:06:01.7    4   0   0  bias    8    -1  -1  -99.0000
# 11   2018-04-29T02:06:37.7    3   0   0  bias    9    -1  -1  -99.0000
# ...
