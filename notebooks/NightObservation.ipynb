# %%
# %matplotlib notebook

# %%
from ztfquery import query

# %%
night = "20180509"
may1018 = query.NightSummary(night)

# %%
fig = may1018.show_gri_fields(title="Observed Fields \n 2018-05-09")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
may1018.get_observed_information()
# Out:
#     field        ra      dec
# 84    471  171.7247   4.5500
# 85    470  164.8829   4.5500
# 86    573  166.2177  18.9500
# 87    570  145.0583  18.9500
# 88    619  143.6189  26.1500
# 89    667  149.0569  33.3500
# 90    668  156.9102  33.3500
# 91    710  140.5491  40.5500
# 92    711  149.1659  40.5500
# 93    712  157.7828  40.5500
# 94    471  171.7247   4.5500
# 95    623  173.5457  26.1500
# 96    470  164.8829   4.5500
# 97    521  157.6745  11.7500
# 98    571  152.1115  18.9500
# 99    570  145.0583  18.9500
# 100   620  151.1006  26.1500
# 101   619  143.6189  26.1500
# 102   668  156.9102  33.3500
# 103   669  164.7635  33.3500
# 104   711  149.1659  40.5500
# 105   712  157.7828  40.5500
# 106   713  166.3995  40.5500
# 107   752  157.2511  47.7500
# 108   713  166.3995  40.5500
# 109   752  157.2511  47.7500
# 110   753  166.6757  47.7500
# 111   789  180.3789  54.9500
# 112   716  192.2500  40.5500
# 113   753  166.6757  47.7500
# ..    ...       ...      ...
# ...

# %%
may1018.get_observed_fields()
# Out:
# array(['470', '471', '472', '521', '524', '525', '526', '529', '530',
#        '570', '571', '573', '574', '575', '577', '578', '579', '582',
#        '588', '619', '620', '621', '622', '623', '624', '625', '627',
#        '630', '631', '633', '634', '667', '668', '669', '670', '671',
#        '672', '673', '675', '676', '677', '678', '679', '680', '681',
#        '682', '710', '711', '712', '713', '714', '715', '716', '717',
#        '718', '719', '720', '721', '723', '724', '725', '752', '753',
#        '754', '755', '756', '757', '758', '759', '760', '761', '762',
#        '764', '786', '787', '788', '789', '790', '791', '792', '793',
#        '794', '797', '816', '817', '818', '819', '820', '821', '822',
#        '823', '824', '825', '842', '843', '844', '845', '846', '847'],
#       dtype=object)

# %%
may1018.data
# Out:
#                   UT_START  sun exp fid  type cnt field pid        ra  \
# 84   2018-05-10T03:49:08.6  -14  30   2  targ   0   471   1  171.7247
# 85   2018-05-10T03:49:48.4  -14  30   2  targ   0   470   1  164.8829
# 86   2018-05-10T03:50:30.5  -15  30   2  targ   0   573   1  166.2177
# 87   2018-05-10T03:54:30.3  -15  30   2  targ   0   570   1  145.0583
# 88   2018-05-10T03:55:49.9  -16  30   2  targ   0   619   1  143.6189
# 89   2018-05-10T03:57:13.2  -16  30   2  targ   0   667   1  149.0569
# 90   2018-05-10T03:57:53.6  -16  30   2  targ   0   668   3  156.9102
# 91   2018-05-10T03:58:37.9  -16  30   2  targ   0   710   1  140.5491
# 92   2018-05-10T03:59:18.6  -16  30   2  targ   0   711   1  149.1659
# 93   2018-05-10T03:59:59.4  -16  30   2  targ   0   712   3  157.7828
# 94   2018-05-10T04:04:52.2  -17  30   1  targ   0   471   1  171.7247
# 95   2018-05-10T04:06:13.8  -17  30   1  targ   0   623   3  173.5457
# ...
