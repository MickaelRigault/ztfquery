# %%
# %matplotlib notebook

# %%
from ztfquery import query

# %%
import requests
import numpy as np

# %%
night = "20180806"
thenight = query.NightSummary(night)
fig = thenight.show_gri_fields(title="Observed Fields \n %s"%night)
# Out:
# <img src="data:image/png;base64,..." width="899.4444682715858">

# %%
print(thenight.get_observed_fields("primary"))
# Out:
# ['246' '247' '277' '278' '279' '280' '281' '289' '290' '295' '296' '297'
#  '298' '299' '326' '327' '328' '329' '330' '332' '333' '338' '339' '340'
#  '345' '350' '351' '375' '376' '377' '378' '383' '384' '390' '395' '396'
#  '397' '402' '403' '404' '426' '427' '428' '435' '436' '440' '442' '446'
#  '447' '448' '449' '451' '452' '453' '476' '477' '483' '484' '487' '488'
#  '497' '498' '499' '500' '501' '502' '504' '505' '527' '528' '529' '532'
#  '533' '534' '535' '536' '537' '538' '539' '540' '551' '552' '553' '554'
#  '555' '577' '578' '579' '582' '583' '584' '585' '586' '587' '588' '590'
#  '591' '602' '603' '604' '605' '606' '612' '625' '626' '627' '628' '630'
#  '631' '632' '633' '634' '635' '636' '637' '639' '640' '649' '651' '652'
#  '653' '658' '659' '672' '673' '674' '676' '677' '678' '679' '680' '681'
#  '682' '686' '687' '695' '696' '697' '700' '702' '703' '715' '716' '717'
#  '719' '720' '721' '722' '723' '724' '725' '729' '730' '737' '740' '741'
# ...

# %%
thenight.data
# Out:
#                   UT_START  sun exp fid  type field pid        ra       dec  \
# 84   2018-08-06T03:42:32.0  -12  30   3  targ   633   2  248.3629   26.1500
# 85   2018-08-06T03:43:14.6  -12  30   3  targ   532   2  236.0507   11.7500
# 86   2018-08-06T03:43:54.1  -12  30   3  targ   583   2  238.0418   18.9500
# 87   2018-08-06T03:44:33.7  -12  30   3  targ   632   2  240.8811   26.1500
# 88   2018-08-06T03:45:15.2  -13  30   3  targ   582   2  230.7732   18.9500
# 89   2018-08-06T03:45:55.6  -13  30   3  targ   630   2  225.9177   26.1500
# 90   2018-08-06T03:46:35.7  -13  30   3  targ   631   2  233.3994   26.1500
# 91   2018-08-06T03:47:20.6  -13  30   3  targ   680   2  251.1496   33.3500
# 92   2018-08-06T03:48:00.9  -13  30   3  targ   679   2  243.2964   33.3500
# 93   2018-08-06T03:48:41.3  -13  30   3  targ   678   2  235.4431   33.3500
# 94   2018-08-06T03:49:21.6  -13  30   3  targ   677   2  227.5898   33.3500
# ...

# %%
may1018.set_metadata("sci", paddedccdid="06", qid="01")

# %%
may1018.download_data(nodl=True)
# Out:
# (['https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/154421/ztf_20180806154421_000633_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/154965/ztf_20180806154965_000532_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/155463/ztf_20180806155463_000583_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/155926/ztf_20180806155926_000632_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/156377/ztf_20180806156377_000582_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/156863/ztf_20180806156863_000630_zi_c06_o_q01_sciimg.fits',
#   'https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2018/0806/157326/ztf_20180806157326_000631_zi_c06_o_q01_sciimg.fits',
# ...

# %%
mask = (may1018.data["type"]=="targ") * (may1018.data["pid"]=="2")
# Out:
# /Users/mrigault/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py:180: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))

# %%
len(may1018.download_data(mask=mask, nodl=True)[0])
# Out:
# 325

# %%
'/Users/mrigault/Data/ZTF/sci/2018/0615/304074/ztf_20180615304074_000762_zr_c06_o_q2_sciimg.fits'

# %%
def filefrac_to_year_monthday_fracday(filefracday):
    """ split the name as YYYY, MMDD, FFFFFF
    FFFFFF (fraction in the day)"""
    return filefracday[:4],filefracday[4:8],filefracday[8:]

# %%
filefrac_to_year_monthday_fracday("20180615304074")
# Out:
# ('2018', '0615', '304074')

# %%
source+'sci/'+year+'/'+month+day+'/'+fracday+'/ztf_'+filefracday+'_'+paddedfield+'_'+filtercode+'_c'+paddedccdid+'_'+imgtypecode+'_q'+qid+'_'+suffix
