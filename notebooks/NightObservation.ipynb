# %%
# %matplotlib notebook

# %%
from ztfquery import query

# %%
import requests
import numpy as np

# %%
night = "20180528"
summary = requests.get(query._NIGHT_SUMMARY_URL+"%s/exp.%s.tbl"%(night,night), auth=("ztf","discover") ).content.decode('utf-8').splitlines()

# %%
summary
# Out:
# ['| UT_START            |sun| exp |fil|type| field |pid| ra     | dec    | slew | wait  | fileroot                     | progpi     | qcomment                |  ',
#  ' 2018-05-28T01:45:49.6  11     0   0 bias      -1  -1 -99.0000 -99.0000  -1.00    19.4 ztf_20180528073484_000000_bi      -         calib                     ',
#  ' 2018-05-28T01:46:09.4  11     0   0 bias      -1  -1 -99.0000 -99.0000  -1.00    19.4 ztf_20180528073704_000000_bi      -         calib                     ',
#  ' 2018-05-28T01:46:28.9  11     0   0 bias      -1  -1 -99.0000 -99.0000  -1.00    19.5 ztf_20180528073935_000000_bi      -         calib                     ',
#  ' 2018-05-28T01:46:48.5  11     0   0 bias      -1  -1 -99.0000 -99.0000  -1.00    19.6 ztf_20180528074155_000000_bi      -         calib                     ',
#  ' 2018-05-28T01:47:08.2  11     0   0 bias      -1  -1 -99.0000 -99.0000  -1.00    19.5 ztf_20180528074387_000000_bi      -         calib                     ',
# ...

# %%
columns = [l.replace(" ","") for l in summary[0].split('|') if len(l.replace(" ",""))>0]
columns
# Out:
# ['UT_START',
#  'sun',
#  'exp',
#  'fil',
#  'type',
#  'field',
#  'pid',
#  'ra',
#  'dec',
#  'slew',
#  'wait',
#  'fileroot',
#  'progpi',
#  'qcomment']

# %%
data    = [l.split() for l in summary[1:] if not l.startswith('|')]

# %%
np.shape(data)
# Out:
# (698, 14)

# %%
night = "20180510"
may1018 = query.NightSummary(night)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-8163b89d1b44> in <module>()
#       1 night = "20180510"
# ----> 2 may1018 = query.NightSummary(night)
#
# ~/anaconda3/lib/python3.6/site-packages/ztfquery-0.5.0-py3.6.egg/ztfquery/query.py in __init__(self, night)
#     475         self.night = night
#     476
# --> 477         self.data_all  = download_night_summary(night)
#     478
#     479         self.data  = self.data_all[self.data_all["type"]=="targ"]
#
# ~/anaconda3/lib/python3.6/site-packages/ztfquery-0.5.0-py3.6.egg/ztfquery/query.py in download_night_summary(night)
#     465     columns = [l.replace(" ","") for l in summary[0].split('|') if len(l)>0]
#     466     data    = [l.split() for l in summary[1:] if not l.startswith('|') and len(l)>1]
# --> 467     dataf   = DataFrame(data=data, columns=[l if l!= "fil" else "fid" for l in columns])
# ...

# %%
fig = may1018.show_gri_fields(title="Observed Fields \n 2018-05-10")
# Out:
# <img src="data:image/png;base64,..." width="450">

# %%
may1018.get_observed_fields("primary")
# Out:
# array(['470', '471', '472', '521', '524', '525', '526', '529', '530',
#        '570', '571', '573', '574', '575', '577', '578', '579', '582',
#        '588', '619', '620', '621', '622', '623', '624', '625', '627',
#        '630', '631', '633', '634', '667', '668', '669', '670', '671',
#        '672', '673', '675', '676', '677', '678', '679', '680', '681',
#        '682', '710', '711', '712', '713', '714', '715', '716', '717',
#        '718', '719', '720', '721', '723', '724', '725', '752', '753',
#        '754', '755', '756', '757', '758', '759', '760', '761', '762',
#        '764', '786', '787', '788', '789', '790', '791', '792', '793',
#        '794', '797', '816', '817', '818', '819', '820', '821', '822',
#        '823', '824', '825', '842', '843', '844', '845', '846', '847'],
#       dtype=object)

# %%
may1018.data
# Out:
#                   UT_START  sun exp fid  type cnt field pid        ra  \
# 84   2018-05-10T03:49:08.6  -14  30   2  targ   0   471   1  171.7247
# 85   2018-05-10T03:49:48.4  -14  30   2  targ   0   470   1  164.8829
# 86   2018-05-10T03:50:30.5  -15  30   2  targ   0   573   1  166.2177
# 87   2018-05-10T03:54:30.3  -15  30   2  targ   0   570   1  145.0583
# 88   2018-05-10T03:55:49.9  -16  30   2  targ   0   619   1  143.6189
# 89   2018-05-10T03:57:13.2  -16  30   2  targ   0   667   1  149.0569
# 90   2018-05-10T03:57:53.6  -16  30   2  targ   0   668   3  156.9102
# 91   2018-05-10T03:58:37.9  -16  30   2  targ   0   710   1  140.5491
# 92   2018-05-10T03:59:18.6  -16  30   2  targ   0   711   1  149.1659
# 93   2018-05-10T03:59:59.4  -16  30   2  targ   0   712   3  157.7828
# 94   2018-05-10T04:04:52.2  -17  30   1  targ   0   471   1  171.7247
# 95   2018-05-10T04:06:13.8  -17  30   1  targ   0   623   3  173.5457
# ...
